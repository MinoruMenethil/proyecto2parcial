# %% [markdown]
# En el presente proyecto se procederá a realizar el proceso ETL mediante el lenguaje de programación Python y la librería de SQLAlchemy que tiene la misma función que otras librerías como sqlite3. A continuación se presenta los pasos que se realizarán para el proceso ETL:
#
#
# 1. Primero, se usará sólamente la tabla Invoice de la base de datos chinook.db
# 2. Para el proceso de transformación se realizará lo siguiente:
# -Se calculará la facturación promedio por factura por país
# -Se procesará los valores nulos en las facturas de tal forma que se los rellene con "Ninguno" y "12345".
# 3. Se cargará los datos transformados dentro de la base de datos chinook.db en una nueva tabla que se llamará "New_Invoice".

# %%
import pandas as pd

# %%
import sqlalchemy

# %%
sqlalchemy.__version__
# Out:
# '1.4.31'

# %%
# Conexión con la base de datos

connection_uri = "sqlite:///chinook.db"

# %%
# Creando un engine: db_engine
db_engine = sqlalchemy.create_engine(connection_uri)

# %% [markdown]
# ## ETL
# ### 1. Preprocessing of Extract

# %%
# Realizamos un inspector con el engine anterior creado para buscar el nombre de las tablas de la base de datos
inspector = sqlalchemy.inspect(db_engine)
table_names = inspector.get_table_names()
table_names
# Out:
# ['New_Invoice',
#  'albums',
#  'artists',
#  'customers',
#  'employees',
#  'genres',
#  'invoice_items',
#  'invoices',
#  'media_types',
#  'playlist_track',
#  'playlists',
#  'sqlite_sequence',
#  'sqlite_stat1',
#  'tracks']

# %%
# Abrimos conexión con el engine: con
con = db_engine.connect()

# %%
# Se realiza una pequeña consulta de prueba
qr_invoice = con.execute("SELECT * FROM invoices")

type(qr_invoice)
# Out:
# sqlalchemy.engine.cursor.LegacyCursorResult

# %%
qr_invoice.keys()
# Out:
# RMKeyView(['InvoiceId', 'CustomerId', 'InvoiceDate', 'BillingAddress', 'BillingCity', 'BillingState', 'BillingCountry', 'BillingPostalCode', 'Total'])

# %%
df = pd.DataFrame(qr_invoice.fetchall())
df.columns = qr_invoice.keys()

# %%
df
# Out:
#      InvoiceId  CustomerId  ... BillingPostalCode  Total
# 0            1           2  ...             70174   1.98
# 1            2           4  ...              0171   3.96
# 2            3           8  ...              1000   5.94
# 3            4          14  ...           T6G 2C7   8.91
# 4            5          23  ...              2113  13.86
# ..         ...         ...  ...               ...    ...
# 407        408          25  ...             53703   3.96
# 408        409          29  ...           M6J 1V1   5.94
# 409        410          35  ...              None   8.91
# 410        411          44  ...             00530  13.86
# 411        412          58  ...            110017   1.99
#
# [412 rows x 9 columns]

# %% [markdown]
# ### 2. Preproceso de transformación
# Se calculará la facturación promedio por factura por país -Se procesará los valores nulos en las facturas de tal forma que se los rellene con "Ninguno" y "12345".
#
# Se cargará los datos transformados dentro de la base de datos chinook.db en una nueva tabla que se llamará "New_Invoice".

# %% [markdown]
# Cálculo del primedio de facturación por factura por país.

# %%
# Se calcula el promedio de factoración por país
df_g = df.groupby(['BillingCountry'])[['Total']].mean()
df_g
# Out:
#                    Total
# BillingCountry
# Argentina       5.374286
# Australia       5.374286
# Austria         6.088571
# Belgium         5.374286
# Brazil          5.431429
# Canada          5.427857
# Chile           6.660000
# Czech Republic  6.445714
# Denmark         5.374286
# Finland         5.945714
# France          5.574286
# Germany         5.588571
# Hungary         6.517143
# India           5.789231
# Ireland         6.517143
# Italy           5.374286
# Netherlands     5.802857
# Norway          5.660000
# Poland          5.374286
# Portugal        5.517143
# Spain           5.374286
# Sweden          5.517143
# USA             5.747912
# United Kingdom  5.374286

# %%
df_g = df_g.reset_index()
df_g.rename(columns = {"Total":"Promedio"}, inplace=True)
df_g.head(5)
# Out:
#   BillingCountry  Promedio
# 0      Argentina  5.374286
# 1      Australia  5.374286
# 2        Austria  6.088571
# 3        Belgium  5.374286
# 4         Brazil  5.431429

# %%
# Uniendo el promedio calculado en el conjunto de datos
df = df.merge(df_g, how="left", left_on = "BillingCountry", right_on = "BillingCountry")
df.head(5)
# Out:
#    InvoiceId  CustomerId  ...  Total  Promedio
# 0          1           2  ...   1.98  5.588571
# 1          2           4  ...   3.96  5.660000
# 2          3           8  ...   5.94  5.374286
# 3          4          14  ...   8.91  5.427857
# 4          5          23  ...  13.86  5.747912
#
# [5 rows x 10 columns]

# %% [markdown]
# ##### Procesando los valores nulos en los atributos y llenándolos con "ninguno" y "12345".

# %%
# Se realiza una consulta para verificar el número de campos nulos en cada atributo
display('Número de campos nulos por cada atributo', df.isnull().sum())
# Out:
# 'Número de campos nulos por cada atributo'
# InvoiceId              0
# CustomerId             0
# InvoiceDate            0
# BillingAddress         0
# BillingCity            0
# BillingState         202
# BillingCountry         0
# BillingPostalCode     28
# Total                  0
# Promedio               0
# dtype: int64

# %%
 df= df.fillna({"BillingState": "Ninguno", "BillingPostalCode":"12345"})

# %%
display('Número de campos nulos por cada atributo: ', df.isnull().sum())
# Out:
# 'Número de campos nulos por cada atributo: '
# InvoiceId            0
# CustomerId           0
# InvoiceDate          0
# BillingAddress       0
# BillingCity          0
# BillingState         0
# BillingCountry       0
# BillingPostalCode    0
# Total                0
# Promedio             0
# dtype: int64

# %%
df
# Out:
#      InvoiceId  CustomerId  ...  Total  Promedio
# 0            1           2  ...   1.98  5.588571
# 1            2           4  ...   3.96  5.660000
# 2            3           8  ...   5.94  5.374286
# 3            4          14  ...   8.91  5.427857
# 4            5          23  ...  13.86  5.747912
# ..         ...         ...  ...    ...       ...
# 407        408          25  ...   3.96  5.747912
# 408        409          29  ...   5.94  5.427857
# 409        410          35  ...   8.91  5.517143
# 410        411          44  ...  13.86  5.945714
# 411        412          58  ...   1.99  5.789231
#
# [412 rows x 10 columns]

# %% [markdown]
# ### 3. Preproceso de carga
# * Se comienza a hacer la carga al  sql

# %%
con

# %%
sqlite_table = "New_Invoice"
df.to_sql(sqlite_table, con, if_exists='fail')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-f0d46e7c3ff0> in <module>()
#       1 sqlite_table = "New_Invoice"
# ----> 2 df.to_sql(sqlite_table, con, if_exists='fail')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2613             chunksize=chunksize,
#    2614             dtype=dtype,
# -> 2615             method=method,
#    2616         )
#    2617
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     596         chunksize=chunksize,
#     597         dtype=dtype,
# --> 598         method=method,
#     599     )
#     600
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1391             dtype=dtype,
#    1392         )
# -> 1393         table.create()
#    1394
#    1395         from sqlalchemy import exc
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in create(self)
#     721         if self.exists():
#     722             if self.if_exists == "fail":
# --> 723                 raise ValueError(f"Table '{self.name}' already exists.")
#     724             elif self.if_exists == "replace":
#     725                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'New_Invoice' already exists.

# %%
con.close()

# %% [markdown]
# ### 4. Creación de las funciones ETL

# %% [markdown]
# Funciónes de estracción:
# Nombre de la función: **extract_table_to_pandas**

# %%
# Función para extraer a través del engine y la conexión de la base de datos. 
def extract_database(path):
    '''
    Input:
        path: Path of the database
        
    Output:
        return 
        db_engine : The engine is get database
        db_connect: The connect is get connection with engine
    '''
    db_engine = sqlalchemy.create_engine(path)
    db_connect = db_engine.connect()
    
    return db_engine, db_connect

# %%
# Función para extraer la tabla hacia el dataframe

def extract_table_to_pandas(tablename, db_connect):
    '''
    Input:
        Table Name: Name of the table to be extracted
        db_connect: The connect to get connection with engine
    Output:
        return 
        df        : The dataframe to be transformed
    '''
    query = "SELECT * FROM {}".format(tablename)
    result = db_connect.execute(query)

    df = pd.DataFrame(result.fetchall())
    df.columns = result.keys()
    
    return df

# %% [markdown]
# Creando funciones de transformación:
# Nombre de la función:
# - **transform_avg_billing**
# - **transform_fill_null**

# %%
# Función de transformación para el promedio 
def transform_avg_billing(data):
    '''
    Group by Country and extract average billing per Invoice
    Input:
        data : The dataframe to get to transform
    Output:
        return dataframe transformed
    '''
    # Cálculo del promedio por país
    df_g = data.groupby(['BillingCountry'])[['Total']].mean()
    df_g = df_g.reset_index()
    df_g.rename(columns = {"Total":"Average"}, inplace=True)
    
    df = data.merge(df_g, how="left", left_on = "BillingCountry", right_on = "BillingCountry")

    return df

# %%
# Función de transformación para rellenar los valores faltantes
def transform_fill_null(data):
    '''
    Some processing about Null values
        "BillingState" > "None"
        "BillingPostalCode" > "99999"
    Input:
        data : The dataframe to get to transform
    Output:
        return dataframe transformed
    '''
    # Proceso de llenado de los valores restantes
    data = data.fillna({"BillingState": "None", "BillingPostalCode":"99999"})

    return data

# %% [markdown]
# Creación de las funciones de carga:

# %%
# Función para cargar un dataframe dentro de una tabla en la base de datos
def loading_to_sql(data, connect, sqlite_table='New_Table'):
    '''
    Input:
        data        : The dataframe to get to loading
        connect     : Name of the engine connection 
        sqlite_table: Table name for loaing
    '''
   
    data.to_sql(sqlite_table, connect, if_exists='fail')
    connect.close()
    return 'Loading is Done'

# %% [markdown]
# ##### 4.4. Testing functions of ETL

# %%
# Main donde se ejecutan las funciones
path = "sqlite:///chinook.db"

# Extrayendo de la base de datos la tabla invoices
extract_db = extract_database(path)

tablename = 'invoices'
engine = extract_db[0]
extract = extract_table_to_pandas(tablename, engine)

# Transformación
transform = transform_avg_billing(extract)
transform = transform_fill_null(transform)

# Carga
data = transform
connect = extract_db[1]
sqlite_table
data.head
# Out:
# <bound method NDFrame.head of      InvoiceId  CustomerId  ...  Total   Average
# 0            1           2  ...   1.98  5.588571
# 1            2           4  ...   3.96  5.660000
# 2            3           8  ...   5.94  5.374286
# 3            4          14  ...   8.91  5.427857
# 4            5          23  ...  13.86  5.747912
# ..         ...         ...  ...    ...       ...
# 407        408          25  ...   3.96  5.747912
# 408        409          29  ...   5.94  5.427857
# 409        410          35  ...   8.91  5.517143
# 410        411          44  ...  13.86  5.945714
# 411        412          58  ...   1.99  5.789231
#
# [412 rows x 10 columns]>
# Exception during reset or similar
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py", line 739, in _finalize_fairy
#     fairy._reset(pool)
#   File "/usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py", line 988, in _reset
#     pool._dialect.do_rollback(self)
#   File "/usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py", line 682, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 139776164472704 and this is thread id 139775504013056.
# Exception closing connection <sqlite3.Connection object at 0x7f200356de30>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py", line 739, in _finalize_fairy
#     fairy._reset(pool)
#   File "/usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py", line 988, in _reset
#     pool._dialect.do_rollback(self)
#   File "/usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py", line 682, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 139776164472704 and this is thread id 139775504013056.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py", line 247, in _close_connection
#     self._dialect.do_close(connection)
#   File "/usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py", line 688, in do_close
#     dbapi_connection.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 139776164472704 and this is thread id 139775504013056.

# %%
# Resultados obtenidos
transform
# Out:
#      InvoiceId  CustomerId  ...  Total   Average
# 0            1           2  ...   1.98  5.588571
# 1            2           4  ...   3.96  5.660000
# 2            3           8  ...   5.94  5.374286
# 3            4          14  ...   8.91  5.427857
# 4            5          23  ...  13.86  5.747912
# ..         ...         ...  ...    ...       ...
# 407        408          25  ...   3.96  5.747912
# 408        409          29  ...   5.94  5.427857
# 409        410          35  ...   8.91  5.517143
# 410        411          44  ...  13.86  5.945714
# 411        412          58  ...   1.99  5.789231
#
# [412 rows x 10 columns]

# %%
# Verificamos que ningun atributo esté vacío
transform.isnull().sum()
# Out:
# InvoiceId            0
# CustomerId           0
# InvoiceDate          0
# BillingAddress       0
# BillingCity          0
# BillingState         0
# BillingCountry       0
# BillingPostalCode    0
# Total                0
# Average              0
# dtype: int64

# %% [markdown]
# Cerramos la conexión con la base de datos para evitar errores.

# %%
con.close()

# %%
# Consulta final de la nueva tabla creada y ver los datos que contiene para darnos cuenta que los campos han sido rellenados con "ninguno" 
# y "12345"
inspector.get_columns('New_Invoice')

with engine.connect() as con:
    
    rs = con.execute('SELECT * FROM New_Invoice')
    
    for row in rs:
        print(row)
con.close()
# Out:
# (0, 1, 2, '2009-01-01 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 1.98, 5.588571428571428)
# (1, 2, 4, '2009-01-02 00:00:00', 'Ullevålsveien 14', 'Oslo', 'None', 'Norway', '0171', 3.96, 5.659999999999999)
# (2, 3, 8, '2009-01-03 00:00:00', 'Grétrystraat 63', 'Brussels', 'None', 'Belgium', '1000', 5.94, 5.374285714285714)
# (3, 4, 14, '2009-01-06 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 8.91, 5.427857142857142)
# (4, 5, 23, '2009-01-11 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 13.86, 5.747912087912091)
# (5, 6, 37, '2009-01-19 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 0.99, 5.588571428571428)
# (6, 7, 38, '2009-02-01 00:00:00', 'Barbarossastraße 19', 'Berlin', 'None', 'Germany', '10779', 1.98, 5.588571428571428)
# (7, 8, 40, '2009-02-01 00:00:00', '8, Rue Hanovre', 'Paris', 'None', 'France', '75002', 1.98, 5.574285714285712)
# (8, 9, 42, '2009-02-02 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 3.96, 5.574285714285712)
# (9, 10, 46, '2009-02-03 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', '99999', 5.94, 6.517142857142857)
# (10, 11, 52, '2009-02-06 00:00:00', '202 Hoxton Street', 'London', 'None', 'United Kingdom', 'N1 5LH', 8.91, 5.374285714285714)
# (11, 12, 2, '2009-02-11 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 13.86, 5.588571428571428)
# (12, 13, 16, '2009-02-19 00:00:00', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', 0.99, 5.747912087912091)
# (13, 14, 17, '2009-03-04 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 1.98, 5.747912087912091)
# (14, 15, 19, '2009-03-04 00:00:00', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', 1.98, 5.747912087912091)
# (15, 16, 21, '2009-03-05 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503',
00:00:00', '8, Rue Hanovre', 'Paris', 'None', 'France', '75002', 5.94, 5.574285714285712)
# (248, 249, 46, '2011-12-27 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', '99999', 8.91, 6.517142857142857)
# (249, 250, 55, '2012-01-01 00:00:00', '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', 13.86, 5.3742857142857146)
# (250, 251, 10, '2012-01-09 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 0.99, 5.431428571428571)
# (251, 252, 11, '2012-01-22 00:00:00', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', 1.98, 5.431428571428571)
# (252, 253, 13, '2012-01-22 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 1.98, 5.431428571428571)
# (253, 254, 15, '2012-01-23 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 3.96, 5.427857142857142)
# (254, 255, 19, '2012-01-24 00:00:00', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', 5.94, 5.747912087912091)
# (255, 256, 25, '2012-01-27 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 8.91, 5.747912087912091)
# (256, 257, 34, '2012-02-01 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', '99999', 13.86, 5.517142857142856)
# (257, 258, 48, '2012-02-09 00:00:00', 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', 0.99, 5.8028571428571425)
# (258, 259, 49, '2012-02-22 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 1.98, 5.3742857142857146)
# (259, 260, 51, '2012-02-22 00:00:00', 'Celsiusg. 9', 'Stockholm', 'None', 'Sweden', '11230', 1.98, 5.517142857142858)
# (260, 261, 53, '2012-02-23 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 3.96, 5.374285714285714)
# (261, 262, 57, '2012-02-24 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', '99999', 5.94, 6.659999999999999)
# (262, 263, 4, '2012-02-27 00:00:00', 'Ullevålsveien 14', 'Oslo', 'None', 'Norway', '0171', 8.91, 5.659999999999999)
# (263, 264, 13, '2012-03-03 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 13.86, 5.431428571428571)
# (264, 265, 27, '2012-03-11 00:00:00', '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', 0.99, 5.747912087912091)
# (265, 266, 28, '2012-03-24 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 1.98, 5.747912087912091)
# (266, 267, 30, '2012-03-24 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 1.98, 5.427857142857142)
# (267, 268, 32, '2012-03-25 00:00:00', '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', 3.96, 5.427857142857142)
# (268, 269, 36, '2012-03-26 00:00:00', 'Tauentzienstraße 8', 'Berlin', 'None', 'Germany', '10789', 5.94, 5.588571428571428)
# (269, 270, 42, '2012-03-29 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 8.91, 5.574285714285712)
# (270, 271, 51, '2012-04-03 00:00:00', 'Celsiusg. 9', 'Stockholm', 'None', 'Sweden', '11230', 13.86, 5.517142857142858)
# (271, 272, 6, '2012-04-11 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 0.99, 6.445714285714287)
# (272, 273, 7, '2012-04-24 00:00:00', 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', 'None', 'Austria', '1010', 1.98, 6.088571428571428)
# (273, 274, 9, '2012-04-24 00:00:00', 'Sønder Boulevard 51', 'Copenhagen', 'None', 'Denmark', '1720', 1.98, 5.3742857142857146)
# (274, 275, 11, '2012-04-25 00:00:00', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', 3.96, 5.431428571428571)
# (275, 276, 15, '2012-04-26 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 5.94, 5.427857142857142)
# (276, 277, 21, '2012-04-29 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 8.91, 5.747912087912091)
# (277, 278, 30, '2012-05-04 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 13.86, 5.427857142857142)
# (278, 279, 44, '2012-05-12 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 0.99, 5.945714285714287)
# (279, 280, 45, '2012-05-25 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 1.98, 6.517142857142857)
# (280, 281, 47, '2012-05-25 00:00:00', 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', 1.98, 5.3742857142857146)
# (281, 282, 49, '2012-05-26 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 3.96, 5.3742857142857146)
# (282, 283, 53, '2012-05-27 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 5.94, 5.374285714285714)
# (283, 284, 59, '2012-05-30 00:00:00', '3,Raj Bhavan Road', 'Bangalore', 'None', 'India', '560001', 8.91, 5.789230769230769)
# (284, 285, 9, '2012-06-04 00:00:00', 'Sønder Boulevard 51', 'Copenhagen', 'None', 'Denmark', '1720', 13.86, 5.3742857142857146)
# (285, 286, 23, '2012-06-12 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 0.99, 5.747912087912091)
# (286, 287, 24, '2012-06-25 00:00:00', '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', 1.98, 5.747912087912091)
# (287, 288, 26, '2012-06-25 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 1.98, 5.747912087912091)
# (288, 289, 28, '2012-06-26 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 3.96, 5.747912087912091)
# (289, 290, 32, '2012-06-27 00:00:00', '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', 5.94, 5.427857142857142)
# (290, 291, 38, '2012-06-30 00:00:00', 'Barbarossastraße 19', 'Berlin', 'None', 'Germany', '10779', 8.91, 5.588571428571428)
# (291, 292, 47, '2012-07-05 00:00:00', 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', 13.86, 5.3742857142857146)
# (292, 293, 2, '2012-07-13 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', 'None', 'Germany', '70174', 0.99, 5.588571428571428)
# (293, 294, 3, '2012-07-26 00:00:00', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', 1.98, 5.427857142857142)
# (294, 295, 5, '2012-07-26 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 1.98, 6.445714285714287)
# (295, 296, 7, '2012-07-27 00:00:00', 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', 'None', 'Austria', '1010', 3.96, 6.088571428571428)
# (296, 297, 11, '2012-07-28 00:00:00', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', 5.94, 5.431428571428571)
# (297, 298, 17, '2012-07-31 00:00:00', '1 Microsoft Way', 'Redmond', 'WA', 'USA', '98052-8300', 10.91, 5.747912087912091)
# (298, 299, 26, '2012-08-05 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 23.86, 5.747912087912091)
# (299, 300, 40, '2012-08-13 00:00:00', '8, Rue Hanovre', 'Paris', 'None', 'France', '75002', 0.99, 5.574285714285712)
# (300, 301, 41, '2012-08-26 00:00:00', '11, Place Bellecour', 'Lyon', 'None', 'France', '69002', 1.98, 5.574285714285712)
# (301, 302, 43, '2012-08-26 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 1.98, 5.574285714285712)
# (302, 303, 45, '2012-08-27 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 3.96, 6.517142857142857)
# (303, 304, 49, '2012-08-28 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 5.94, 5.3742857142857146)
# (304, 305, 55, '2012-08-31 00:00:00', '421 Bourke Street', 'Sidney', 'NSW', 'Australia', '2010', 8.91, 5.3742857142857146)
# (305, 306, 5, '2012-09-05 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 16.86, 6.445714285714287)
# (306, 307, 19, '2012-09-13 00:00:00', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', 1.99, 5.747912087912091)
# (307, 308, 20, '2012-09-26 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 3.98, 5.747912087912091)
# (308, 309, 22, '2012-09-26 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 3.98, 5.747912087912091)
# (309, 310, 24, '2012-09-27 00:00:00', '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', 7.96, 5.747912087912091)
# (310, 311, 28, '2012-09-28 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 11.94, 5.747912087912091)
# (311, 312, 34, '2012-10-01 00:00:00', 'Rua da Assunção 53', 'Lisbon', 'None', 'Portugal', '99999', 10.91, 5.517142857142856)
# (312, 313, 43, '2012-10-06 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 16.86, 5.574285714285712)
# (313, 314, 57, '2012-10-14 00:00:00', 'Calle Lira, 198', 'Santiago', 'None', 'Chile', '99999', 0.99, 6.659999999999999)
# (314, 315, 58, '2012-10-27 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 1.98, 5.789230769230769)
# (315, 316, 1, '2012-10-27 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 1.98, 5.431428571428571)
# (316, 317, 3, '2012-10-28 00:00:00', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', 3.96, 5.427857142857142)
# (317, 318, 7, '2012-10-29 00:00:00', 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', 'None', 'Austria', '1010', 5.94, 6.088571428571428)
# (318, 319, 13, '2012-11-01 00:00:00', 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', 8.91, 5.431428571428571)
# (319, 320, 22, '2012-11-06 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 13.86, 5.747912087912091)
# (320, 321, 36, '2012-11-14 00:00:00', 'Tauentzienstraße 8', 'Berlin', 'None', 'Germany', '10789', 0.99, 5.588571428571428)
# (321, 322, 37, '2012-11-27 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 1.98, 5.588571428571428)
# (322, 323, 39, '2012-11-27 00:00:00', '4, Rue Milton', 'Paris', 'None', 'France', '75009', 1.98, 5.574285714285712)
# (323, 324, 41, '2012-11-28 00:00:00', '11, Place Bellecour', 'Lyon', 'None', 'France', '69002', 3.96, 5.574285714285712)
# (324, 325, 45, '2012-11-29 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 5.94, 6.517142857142857)
# (325, 326, 51, '2012-12-02 00:00:00', 'Celsiusg. 9', 'Stockholm', 'None', 'Sweden', '11230', 8.91, 5.517142857142858)
# (326, 327, 1, '2012-12-07 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 13.86, 5.431428571428571)
# (327, 328, 15, '2012-12-15 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 0.99, 5.427857142857142)
# (328, 329, 16, '2012-12-28 00:00:00', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', 1.98, 5.747912087912091)
# (329, 330, 18, '2012-12-28 00:00:00', '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', 1.98, 5.747912087912091)
# (330, 331, 20, '2012-12-29 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 3.96, 5.747912087912091)
# (331, 332, 24, '2012-12-30 00:00:00', '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', 5.94, 5.747912087912091)
# (332, 333, 30, '2013-01-02 00:00:00', '230 Elgin Street', 'Ottawa', 'ON', 'Canada', 'K2P 1L7', 8.91, 5.427857142857142)
# (333, 334, 39, '2013-01-07 00:00:00', '4, Rue Milton', 'Paris', 'None', 'France', '75009', 13.86, 5.574285714285712)
# (334, 335, 53, '2013-01-15 00:00:00', '113 Lupus St', 'London', 'None', 'United Kingdom', 'SW1V 3EN', 0.99, 5.374285714285714)
# (335, 336, 54, '2013-01-28 00:00:00', '110 Raeburn Pl', 'Edinburgh ', 'None', 'United Kingdom', 'EH4 1HH', 1.98, 5.374285714285714)
# (336, 337, 56, '2013-01-28 00:00:00', '307 Macacha Güemes', 'Buenos Aires', 'None', 'Argentina', '1106', 1.98, 5.3742857142857146)
# (337, 338, 58, '2013-01-29 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 3.96, 5.789230769230769)
# (338, 339, 3, '2013-01-30 00:00:00', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', 5.94, 5.427857142857142)
# (339, 340, 9, '2013-02-02 00:00:00', 'Sønder Boulevard 51', 'Copenhagen', 'None', 'Denmark', '1720', 8.91, 5.3742857142857146)
# (340, 341, 18, '2013-02-07 00:00:00', '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', 13.86, 5.747912087912091)
# (341, 342, 32, '2013-02-15 00:00:00', '696 Osborne Street', 'Winnipeg', 'MB', 'Canada', 'R3L 2B9', 0.99, 5.427857142857142)
# (342, 343, 33, '2013-02-28 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 1.98, 5.427857142857142)
# (343, 344, 35, '2013-02-28 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', '99999', 1.98, 5.517142857142856)
# (344, 345, 37, '2013-03-01 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 3.96, 5.588571428571428)
# (345, 346, 41, '2013-03-02 00:00:00', '11, Place Bellecour', 'Lyon', 'None', 'France', '69002', 5.94, 5.574285714285712)
# (346, 347, 47, '2013-03-05 00:00:00', 'Via Degli Scipioni, 43', 'Rome', 'RM', 'Italy', '00192', 8.91, 5.3742857142857146)
# (347, 348, 56, '2013-03-10 00:00:00', '307 Macacha Güemes', 'Buenos Aires', 'None', 'Argentina', '1106', 13.86, 5.3742857142857146)
# (348, 349, 11, '2013-03-18 00:00:00', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', 0.99, 5.431428571428571)
# (349, 350, 12, '2013-03-31 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 1.98, 5.431428571428571)
# (350, 351, 14, '2013-03-31 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 1.98, 5.427857142857142)
# (351, 352, 16, '2013-04-01 00:00:00', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', 3.96, 5.747912087912091)
# (352, 353, 20, '2013-04-02 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 5.94, 5.747912087912091)
# (353, 354, 26, '2013-04-05 00:00:00', '2211 W Berry Street', 'Fort Worth', 'TX', 'USA', '76110', 8.91, 5.747912087912091)
# (354, 355, 35, '2013-04-10 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', '99999', 13.86, 5.517142857142856)
# (355, 356, 49, '2013-04-18 00:00:00', 'Ordynacka 10', 'Warsaw', 'None', 'Poland', '00-358', 0.99, 5.3742857142857146)
# (356, 357, 50, '2013-05-01 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 1.98, 5.374285714285714)
# (357, 358, 52, '2013-05-01 00:00:00', '202 Hoxton Street', 'London', 'None', 'United Kingdom', 'N1 5LH', 1.98, 5.374285714285714)
# (358, 359, 54, '2013-05-02 00:00:00', '110 Raeburn Pl', 'Edinburgh ', 'None', 'United Kingdom', 'EH4 1HH', 3.96, 5.374285714285714)
# (359, 360, 58, '2013-05-03 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 5.94, 5.789230769230769)
# (360, 361, 5, '2013-05-06 00:00:00', 'Klanova 9/506', 'Prague', 'None', 'Czech Republic', '14700', 8.91, 6.445714285714287)
# (361, 362, 14, '2013-05-11 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 13.86, 5.427857142857142)
# (362, 363, 28, '2013-05-19 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 0.99, 5.747912087912091)
# (363, 364, 29, '2013-06-01 00:00:00', '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', 1.98, 5.427857142857142)
# (364, 365, 31, '2013-06-01 00:00:00', '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', 1.98, 5.427857142857142)
# (365, 366, 33, '2013-06-02 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 3.96, 5.427857142857142)
# (366, 367, 37, '2013-06-03 00:00:00', 'Berger Straße 10', 'Frankfurt', 'None', 'Germany', '60316', 5.94, 5.588571428571428)
# (367, 368, 43, '2013-06-06 00:00:00', '68, Rue Jouvence', 'Dijon', 'None', 'France', '21000', 8.91, 5.574285714285712)
# (368, 369, 52, '2013-06-11 00:00:00', '202 Hoxton Street', 'London', 'None', 'United Kingdom', 'N1 5LH', 13.86, 5.374285714285714)
# (369, 370, 7, '2013-06-19 00:00:00', 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', 'None', 'Austria', '1010', 0.99, 6.088571428571428)
# (370, 371, 8, '2013-07-02 00:00:00', 'Grétrystraat 63', 'Brussels', 'None', 'Belgium', '1000', 1.98, 5.374285714285714)
# (371, 372, 10, '2013-07-02 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 1.98, 5.431428571428571)
# (372, 373, 12, '2013-07-03 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 3.96, 5.431428571428571)
# (373, 374, 16, '2013-07-04 00:00:00', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', 5.94, 5.747912087912091)
# (374, 375, 22, '2013-07-07 00:00:00', '120 S Orange Ave', 'Orlando', 'FL', 'USA', '32801', 8.91, 5.747912087912091)
# (375, 376, 31, '2013-07-12 00:00:00', '194A Chain Lake Drive', 'Halifax', 'NS', 'Canada', 'B3S 1C5', 13.86, 5.427857142857142)
# (376, 377, 45, '2013-07-20 00:00:00', 'Erzsébet krt. 58.', 'Budapest', 'None', 'Hungary', 'H-1073', 0.99, 6.517142857142857)
# (377, 378, 46, '2013-08-02 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', '99999', 1.98, 6.517142857142857)
# (378, 379, 48, '2013-08-02 00:00:00', 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', 1.98, 5.8028571428571425)
# (379, 380, 50, '2013-08-03 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 3.96, 5.374285714285714)
# (380, 381, 54, '2013-08-04 00:00:00', '110 Raeburn Pl', 'Edinburgh ', 'None', 'United Kingdom', 'EH4 1HH', 5.94, 5.374285714285714)
# (381, 382, 1, '2013-08-07 00:00:00', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', 8.91, 5.431428571428571)
# (382, 383, 10, '2013-08-12 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 13.86, 5.431428571428571)
# (383, 384, 24, '2013-08-20 00:00:00', '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', 0.99, 5.747912087912091)
# (384, 385, 25, '2013-09-02 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 1.98, 5.747912087912091)
# (385, 386, 27, '2013-09-02 00:00:00', '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', 1.98, 5.747912087912091)
# (386, 387, 29, '2013-09-03 00:00:00', '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', 3.96, 5.427857142857142)
# (387, 388, 33, '2013-09-04 00:00:00', '5112 48 Street', 'Yellowknife', 'NT', 'Canada', 'X1A 1N6', 5.94, 5.427857142857142)
# (388, 389, 39, '2013-09-07 00:00:00', '4, Rue Milton', 'Paris', 'None', 'France', '75009', 8.91, 5.574285714285712)
# (389, 390, 48, '2013-09-12 00:00:00', 'Lijnbaansgracht 120bg', 'Amsterdam', 'VV', 'Netherlands', '1016', 13.86, 5.8028571428571425)
# (390, 391, 3, '2013-09-20 00:00:00', '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', 0.99, 5.427857142857142)
# (391, 392, 4, '2013-10-03 00:00:00', 'Ullevålsveien 14', 'Oslo', 'None', 'Norway', '0171', 1.98, 5.659999999999999)
# (392, 393, 6, '2013-10-03 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 1.98, 6.445714285714287)
# (393, 394, 8, '2013-10-04 00:00:00', 'Grétrystraat 63', 'Brussels', 'None', 'Belgium', '1000', 3.96, 5.374285714285714)
# (394, 395, 12, '2013-10-05 00:00:00', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', 5.94, 5.431428571428571)
# (395, 396, 18, '2013-10-08 00:00:00', '627 Broadway', 'New York', 'NY', 'USA', '10012-2612', 8.91, 5.747912087912091)
# (396, 397, 27, '2013-10-13 00:00:00', '1033 N Park Ave', 'Tucson', 'AZ', 'USA', '85719', 13.86, 5.747912087912091)
# (397, 398, 41, '2013-10-21 00:00:00', '11, Place Bellecour', 'Lyon', 'None', 'France', '69002', 0.99, 5.574285714285712)
# (398, 399, 42, '2013-11-03 00:00:00', '9, Place Louis Barthou', 'Bordeaux', 'None', 'France', '33000', 1.98, 5.574285714285712)
# (399, 400, 44, '2013-11-03 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 1.98, 5.945714285714287)
# (400, 401, 46, '2013-11-04 00:00:00', '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', '99999', 3.96, 6.517142857142857)
# (401, 402, 50, '2013-11-05 00:00:00', 'C/ San Bernardo 85', 'Madrid', 'None', 'Spain', '28015', 5.94, 5.374285714285714)
# (402, 403, 56, '2013-11-08 00:00:00', '307 Macacha Güemes', 'Buenos Aires', 'None', 'Argentina', '1106', 8.91, 5.3742857142857146)
# (403, 404, 6, '2013-11-13 00:00:00', 'Rilská 3174/6', 'Prague', 'None', 'Czech Republic', '14300', 25.86, 6.445714285714287)
# (404, 405, 20, '2013-11-21 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 0.99, 5.747912087912091)
# (405, 406, 21, '2013-12-04 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 1.98, 5.747912087912091)
# (406, 407, 23, '2013-12-04 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 1.98, 5.747912087912091)
# (407, 408, 25, '2013-12-05 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 3.96, 5.747912087912091)
# (408, 409, 29, '2013-12-06 00:00:00', '796 Dundas Street West', 'Toronto', 'ON', 'Canada', 'M6J 1V1', 5.94, 5.427857142857142)
# (409, 410, 35, '2013-12-09 00:00:00', 'Rua dos Campeões Europeus de Viena, 4350', 'Porto', 'None', 'Portugal', '99999', 8.91, 5.517142857142856)
# (410, 411, 44, '2013-12-14 00:00:00', 'Porthaninkatu 9', 'Helsinki', 'None', 'Finland', '00530', 13.86, 5.945714285714287)
# (411, 412, 58, '2013-12-22 00:00:00', '12,Community Centre', 'Delhi', 'None', 'India', '110017', 1.99, 5.789230769230769)
